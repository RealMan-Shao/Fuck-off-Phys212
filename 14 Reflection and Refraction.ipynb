# %%
#14 Dec 2022, Realman
import math as m
import numpy as np
#Deg to Rad
def DtR(x):
    return(x/360*2*m.pi)
def RtD(x):
    return(x*360/2/m.pi)

print("#Refraction\n55")

print("\n#Monochromatic Light and a 30-60-90 Prism")
φ1 = 39.8
d = 54.5
h = 20
#Q1
φ2=np.arctan(h/(d-h*3**0.5))
print(RtD(φ2))
#Q2
in1=DtR(60-φ1)
in2=m.pi/3-φ2
n=m.sin(in1)/m.sin(in2)
print(n)
#Q3
in3=m.pi/2-φ2
tmp3=(n*np.sin(in3))
out3=np.arcsin(tmp3)
φ3=90-RtD(out3)
print(φ3)
#Q4
φ2=m.pi/2-np.arcsin(1/n)
in2=m.pi/3-φ2
in1=np.arcsin(n*np.sin(in2))
φ1=60-RtD(in1)
print(φ1)
#Q6
n=1.45 
tmp3=(n*np.sin(np.pi/6))
out3=np.arcsin(tmp3)
φ3=90-RtD(out3)
print(φ3)

print("\n#Single Lens System")
x2 = 102.1
x1= 50.3
y1=5.3
n = 1.48
#Q1
flens=x1*x2/(x1+x2)
print(flens)
#Q2
y2=x2/-x1*y1
print(y2)
#Q3
Rlens=(n-1)*flens
print(Rlens)
#Q4
x11=17.2
x2=flens*x11/(x11-flens)
print(x2)
