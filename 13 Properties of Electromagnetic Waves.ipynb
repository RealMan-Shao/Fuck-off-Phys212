# %%
#7 Dec 2022, Realman
import math as m

print("# Electromagnetic Wave I")
print(-6.14e-7,"\n")

print("# Electromagnetic Wave II")

#Q1
lam=4.6e-2
c=3e8
f=c/lam
print (f/1e9,"GHz")

#Q2
Z0=377
Bx=2.7e-6
By=4.5e-6
E=c*(Bx**2+By**2)**0.5
I=E**2/Z0/2
print(I)

#Q3
B=(Bx**2+By**2)**0.5
S=-E*B/(4e-7*m.pi)
print(S)

#Q4
sinB=By/B
Ex=-E*sinB
print(Ex,"\n")

print("# Polarization")
print(76,"\n")

print("# Polarizers")
#Q1
I0=562
t1=90
t1arc=t1/360*2*m.pi
t2=70
t2arc=t2/360*2*m.pi
t3=30
t3arc=t3/360*2*m.pi
I2=I0*0.5*(m.cos(t1arc-t2arc))**2
print(I2)

#Q2
I3=I2*(m.cos(t2arc-t3arc))**2
print(I3)

#Q3
Inew=I0*0.5*(m.cos(t1arc-t3arc))**2*(m.cos(t2arc-t3arc))**2
print(Inew)

#Q5
Ifnew=I0*0.5*(m.cos(t2arc-t3arc))**2*(m.cos(t3arc))**2
print(Ifnew)

print("\n""# Polarizers and a Quarter-Wave Plate")
#Q1
Io = 379
Imid=0.5*Io
print(Imid )

#Q2
θ1 = 71
Ifinal=Imid*(m.cos(θ1/360*2*m.pi))**2
print(Ifinal)

#Q3
ratio2 =Ifinal*(m.sin(θ1/360*2*m.pi))**2/Io
print(ratio2**0.5)

#Q4
Inew=Io*(m.cos((90-θ1)/360*2*m.pi))**2*(m.cos(θ1/360*2*m.pi))**2
print(Inew)
