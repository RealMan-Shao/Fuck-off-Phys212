# %%
#21 Dec 2022, Realman
import math as m
import numpy as np
#Deg to Rad
def DtR(x):
    return(x/360*2*m.pi)
def RtD(x):
    return(x*360/2/m.pi)

print("#Single Mirror Sysytem ")
x1=115
x2=88.5
y1=6.3
y2=y1/x1*x2
#Q1
f=1/(1/x1+1/x2)
print(f)
#Q2
print(-y2)
#Q3
xnew=177
x1=1/(1/f-1/xnew)
ynew=y1/x1*xnew
print(-ynew)
#Q4
x1=28.5
x2=1/(1/f-1/x1)
y2=y1/x1*x2
print(-y2)

print("\n#Lens System ")
v=1/(1/50-1/75)
f2=1/(1/50+1/200)
print(f2)

print("\n#Two Converging Lenses")
f1=8.6
x2=57.35
f2=20.9
x0=-12
y0=6.9
#Q1
x1=1/(1/f1+1/x0)
print(x1)
#Q2
y1=y0/x0*x1
print(y1)
#Q3
v=x2-x1
x3=1/(1/f2-1/v)+x2
print(x3)
y3=y1/v*(x3-x2)
print(-y3)

print("\n#Two Lens System with Diverging Lens")
f1=-11.3 
x2=25.2
x3=57
x0=-35.7
y0=20.5
#Q1
x1=1/(1/f1+1/x0)
print(x1)
#Q2
y1=y0/x0*x1
print(y1)
#Q3
v=x2-x1
f2=1/(1/v+1/(x3-x2))
print(f2)
y3=y1/v*(x3-x2)
print(-y3)
